# %%
###############    V1    ################

import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# 1. Load Data
with open('intents.json', 'r') as f:
    data = json.load(f)

sentences = []
labels = []
for intent in data['intents']:
    for pattern in intent['patterns']:
        sentences.append(pattern.lower())
        labels.append(intent['tag'])

# 2. Tokenization & Metadata
# We need to save the 'vocab' so your React Native app knows which number belongs to which word
vocab_size = 1000
embedding_dim = 16
max_len = 20
trunc_type = 'post'
oov_tok = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(sentences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, truncating=trunc_type)

# 3. Label Encoding
lbl_encoder = LabelEncoder()
lbl_encoder.fit(labels)
training_labels = lbl_encoder.transform(labels)
num_classes = len(lbl_encoder.classes_)

# 4. Build the Model (Keras)
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_len),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(padded_sequences, np.array(training_labels), epochs=100)

# 5. Export to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('med_intent-1.tflite', 'wb') as f:
    f.write(tflite_model)

# 6. SAVE THESE FOR REACT NATIVE
# Save the word index (Vocabulary)
with open('vocab-1.json', 'w') as f:
    json.dump(word_index, f)

# Save the labels list
with open('labels-1.txt', 'w') as f:
    for label in lbl_encoder.classes_:
        f.write(label + '\n')

print("Files generated: med_intent-1.tflite, vocab-1.json, labels-1.txt")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.0164 - loss: 3.9515
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0408 - loss: 3.9485
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0300 - loss: 3.9453
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0318 - loss: 3.9420
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0453 - loss: 3.9388
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0360 - loss: 3.9276
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0316 - loss: 3.9209
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0357 - loss: 3.9207
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0263 - loss: 3.9097
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0344 - loss: 3.8939
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0397 - loss: 3.8664
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0541 - loss: 3.8418
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0409 - loss: 3.8044
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0535 - loss: 3.7553
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0460 - loss: 3.7232
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0638 - loss: 3.6487
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0630 - loss: 3.6145
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0688 - loss: 3.5515
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1002 - loss: 3.4735
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1149 - loss: 3.3933
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1113 - loss: 3.2812
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1271 - loss: 3.2349
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1847 - loss: 3.1299
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1869 - loss: 3.0412
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1925 - loss: 2.9738
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2241 - loss: 2.8889
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2527 - loss: 2.7862
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2782 - loss: 2.7021
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2613 - loss: 2.6300
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3138 - loss: 2.5599
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3132 - loss: 2.5082
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3345 - loss: 2.4498
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3576 - loss: 2.4105
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3571 - loss: 2.3541
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3817 - loss: 2.2761
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4335 - loss: 2.2198
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4351 - loss: 2.1783
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3886 - loss: 2.1735
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4378 - loss: 2.1550
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4523 - loss: 2.0689
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4708 - loss: 2.0302
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4779 - loss: 1.9668
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5375 - loss: 1.9204
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4874 - loss: 1.8870
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5142 - loss: 1.8828
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5136 - loss: 1.8638
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5537 - loss: 1.8085
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5571 - loss: 1.7800
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5572 - loss: 1.7896
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5630 - loss: 1.7935
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5621 - loss: 1.7157
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5737 - loss: 1.6821
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5831 - loss: 1.6692
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6073 - loss: 1.6327
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6376 - loss: 1.6150
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 1.5660
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6139 - loss: 1.5644
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6442 - loss: 1.5563
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6557 - loss: 1.4893
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6633 - loss: 1.4740
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6617 - loss: 1.4516
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6903 - loss: 1.4875
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6852 - loss: 1.4176
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6838 - loss: 1.3875
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7223 - loss: 1.3417
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6880 - loss: 1.3806
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6904 - loss: 1.3926
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7066 - loss: 1.3321
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7021 - loss: 1.3077
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7158 - loss: 1.3021
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7149 - loss: 1.2811
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7291 - loss: 1.2421
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6808 - loss: 1.3194
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7223 - loss: 1.2372
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7102 - loss: 1.2354
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7413 - loss: 1.2170
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7354 - loss: 1.2037
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7745 - loss: 1.1582
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7735 - loss: 1.1091
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7845 - loss: 1.0920
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7744 - loss: 1.1022
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7516 - loss: 1.1226
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7821 - loss: 1.1067
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7694 - loss: 1.0957
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7649 - loss: 1.0704
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7547 - loss: 1.0547
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7804 - loss: 1.0407
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7788 - loss: 1.0638
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8124 - loss: 0.9858
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7999 - loss: 1.0354
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7574 - loss: 1.0372
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8233 - loss: 0.9654
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7886 - loss: 0.9871
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7844 - loss: 1.0117
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8156 - loss: 0.9196
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8340 - loss: 0.9015
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8256 - loss: 0.9540
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8104 - loss: 0.9554
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7979 - loss: 0.9053
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8383 - loss: 0.8803
# Saved artifact at '/tmp/tmp1kk7j5cu'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 20), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 52), dtype=tf.float32, name=None)
# Captures:
#   135209945227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135209945227408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135209945229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135209945228944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135209945231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135209945230672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135209945231632: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Files generated: med_intent.tflite, vocab.json, labels.txt

# %%
###############    V2    ################

import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# 1. Load Data
# Ensure you have uploaded 'intents.json' to Colab first!
with open('intents.json', 'r') as f:
    data = json.load(f)

sentences = []
labels = []
for intent in data['intents']:
    for pattern in intent['patterns']:
        sentences.append(pattern.lower())
        labels.append(intent['tag'])

# 2. Tokenization & Metadata (Hyperparameters optimized for CNN)
vocab_size = 1000
embedding_dim = 32 # Increased for better feature representation
max_len = 20
trunc_type = 'post'
oov_tok = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(sentences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, truncating=trunc_type)

# 3. Label Encoding
lbl_encoder = LabelEncoder()
lbl_encoder.fit(labels)
training_labels = lbl_encoder.transform(labels)
num_classes = len(lbl_encoder.classes_)

# 4. Build the "Pro" 1D-CNN Model
model = tf.keras.Sequential([
    # Embedding: Turns words into dense vectors
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_len),

    # 1D-CNN: Captures relationships between neighboring words (n-grams)
    tf.keras.layers.Conv1D(64, 5, activation='relu'),

    # Global Max Pooling: Extracts the most important "emergency signal" from the sentence
    tf.keras.layers.GlobalMaxPooling1D(),

    # Fully Connected Layers
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.2), # Dropout layer for better generalization (Resume point!)
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train for 100 epochs (CNNs learn fast, but need enough epochs to converge)
model.fit(padded_sequences, np.array(training_labels), epochs=100)

# 5. Export to TFLite (Optimized for Mobile)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
# Optional: converter.optimizations = [tf.lite.Optimize.DEFAULT] # Adds Quantization (Smaller model)
tflite_model = converter.convert()

with open('med_intent-2.tflite', 'wb') as f:
    f.write(tflite_model)

# 6. SAVE THESE FOR YOUR TEAMMATES
# vocab.json: For the "Tokenizer Bridge" task
with open('vocab-2.json', 'w') as f:
    json.dump(word_index, f)

# labels.txt: The map for the UI to display the right name
with open('labels-2.txt', 'w') as f:
    for label in lbl_encoder.classes_:
        f.write(label + '\n')

print("\n--- ALL DONE ---")
print("Download these from the sidebar: med_intent-2.tflite, vocab-2.json, labels-2.txt")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.0252 - loss: 3.9513
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0509 - loss: 3.9361
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0752 - loss: 3.9109
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1037 - loss: 3.8472
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1433 - loss: 3.6701
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2191 - loss: 3.3682
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2487 - loss: 2.9910
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3438 - loss: 2.5066
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4574 - loss: 2.1941
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5412 - loss: 1.8829
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6177 - loss: 1.5605
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6788 - loss: 1.3301
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7504 - loss: 1.1702
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7905 - loss: 0.9688
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8005 - loss: 0.8669
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8241 - loss: 0.7937
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8405 - loss: 0.6656
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8770 - loss: 0.5769
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8699 - loss: 0.5420
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8814 - loss: 0.5357
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8836 - loss: 0.4643
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9017 - loss: 0.3960
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8946 - loss: 0.3836
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9417 - loss: 0.2966
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9235 - loss: 0.3233
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9207 - loss: 0.2904
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9305 - loss: 0.3034
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.2343
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9590 - loss: 0.2128
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9407 - loss: 0.2194
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9412 - loss: 0.2310
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9548 - loss: 0.1879
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9494 - loss: 0.2285
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9578 - loss: 0.1905
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9714 - loss: 0.1526
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9492 - loss: 0.1891
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9641 - loss: 0.1283
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9590 - loss: 0.1821
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9578 - loss: 0.1677
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9529 - loss: 0.1462
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9753 - loss: 0.1133
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9808 - loss: 0.1206
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9663 - loss: 0.1263
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9730 - loss: 0.1261
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9759 - loss: 0.1257
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9764 - loss: 0.1073
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9686 - loss: 0.1006
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9749 - loss: 0.1106
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9756 - loss: 0.1038
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9833 - loss: 0.0868
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9858 - loss: 0.0801
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9833 - loss: 0.0946
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9697 - loss: 0.0988
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9844 - loss: 0.0912
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9766 - loss: 0.0974
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9736 - loss: 0.0991
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0596
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9797 - loss: 0.0766
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9772 - loss: 0.0844
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9800 - loss: 0.0881
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9844 - loss: 0.0715
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9813 - loss: 0.0743
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9848 - loss: 0.0701
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9949 - loss: 0.0511
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9815 - loss: 0.0674
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9824 - loss: 0.0800
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9850 - loss: 0.0577
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.0704
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9877 - loss: 0.0540
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0601
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9765 - loss: 0.0744
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9915 - loss: 0.0446
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0575
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9858 - loss: 0.0517
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9916 - loss: 0.0502
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9829 - loss: 0.0563
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9886 - loss: 0.0428
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9953 - loss: 0.0366
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9841 - loss: 0.0566
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9873 - loss: 0.0527
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9845 - loss: 0.0550
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9880 - loss: 0.0491
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9897 - loss: 0.0407
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9936 - loss: 0.0405
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0671
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9928 - loss: 0.0394
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9828 - loss: 0.0481
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9859 - loss: 0.0618
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9922 - loss: 0.0360
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9859 - loss: 0.0667
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9863 - loss: 0.0361
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9862 - loss: 0.0544
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9892 - loss: 0.0433
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0471
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9908 - loss: 0.0439
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9906 - loss: 0.0444
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9833 - loss: 0.0560
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9859 - loss: 0.0429
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0313
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9815 - loss: 0.0428
# Saved artifact at '/tmp/tmp8er87ri0'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 20), dtype=tf.float32, name='keras_tensor_6')
# Output Type:
#   TensorSpec(shape=(None, 52), dtype=tf.float32, name=None)
# Captures:
#   135209947200784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135208208421456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135208208422032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135208208422800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135208208423568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135209947196176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135208208422992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# --- ALL DONE ---
# Download these from the sidebar: med_intent.tflite, vocab.json, labels.txt

# %%
###############    V3    ################

import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# 1. Preprocessing Function (Use the EXACT same one in React Native!)
STOP_WORDS = ["help", "i", "think", "got", "my", "me", "the", "a", "an", "please", "somebody", "do", "does"]

def clean_text(text):
    text = text.lower()
    # Remove basic punctuation
    for char in '?!.,':
        text = text.replace(char, '')
    # Remove stop words
    words = text.split()
    filtered = [w for w in words if w not in STOP_WORDS]
    return " ".join(filtered)

# 2. Load and Clean Data
with open('intents.json', 'r') as f:
    data = json.load(f)

sentences = []
labels = []
for intent in data['intents']:
    for pattern in intent['patterns']:
        cleaned_pattern = clean_text(pattern)
        if cleaned_pattern: # Ensure it's not empty after cleaning
            sentences.append(cleaned_pattern)
            labels.append(intent['tag'])

# 3. Tokenization (Using the cleaned sentences)
vocab_size = 1000
max_len = 15 # Reduced since sentences are shorter now
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

# 4. Label Encoding
lbl_encoder = LabelEncoder()
training_labels = lbl_encoder.fit_transform(labels)
num_classes = len(lbl_encoder.classes_)

# 5. Build CNN Model (The "Pro" configuration from before)
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, 16, input_length=max_len),
    tf.keras.layers.Conv1D(32, 3, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(padded_sequences, np.array(training_labels), epochs=150, verbose=0)

# 6. Export Files
# (Same export code as before for .tflite, vocab.json, and labels.txt)

# 5. Export to TFLite (Optimized for Mobile)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
# Optional: converter.optimizations = [tf.lite.Optimize.DEFAULT] # Adds Quantization (Smaller model)
tflite_model = converter.convert()

with open('med_intent-3.tflite', 'wb') as f:
    f.write(tflite_model)

# 6. SAVE THESE FOR YOUR TEAMMATES
# vocab.json: For the "Tokenizer Bridge" task
with open('vocab-3.json', 'w') as f:
    json.dump(word_index, f)

# labels.txt: The map for the UI to display the right name
with open('labels-3.txt', 'w') as f:
    for label in lbl_encoder.classes_:
        f.write(label + '\n')

print("\n--- ALL DONE ---")
print("Download these from the sidebar: med_intent-3.tflite, vocab-3.json, labels-3.txt")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Saved artifact at '/tmp/tmp7iwipb47'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 15), dtype=tf.float32, name='keras_tensor_41')
# Output Type:
#   TensorSpec(shape=(None, 52), dtype=tf.float32, name=None)
# Captures:
#   135207619416464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619415504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619415120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619412624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619415696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619414736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619416848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# --- ALL DONE ---
# Download these from the sidebar: med_intent.tflite, vocab.json, labels.txt

# %%
###############    V4    ################

import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# 1. Body Part Augmentation List
body_parts = ["ribs", "chest", "skull", "wrist", "ankle", "hip", "spine", "nose", "toe", "shoulder", "jaw"]
fracture_synonyms = ["fractured", "broken", "cracked", "snapped"]

# 2. Preprocessing Function
STOP_WORDS = ["help", "i", "think", "got", "my", "me", "the", "a", "an", "please", "somebody"]

def clean_text(text):
    text = text.lower()
    for char in '?!.,': text = text.replace(char, '')
    return " ".join([w for w in text.split() if w not in STOP_WORDS])

# 3. Load and Augment Data
with open('intents.json', 'r') as f:
    data = json.load(f)

sentences = []
labels = []

for intent in data['intents']:
    tag = intent['tag']

    # 1. Add original patterns
    for pattern in intent['patterns']:
        cleaned = clean_text(pattern)
        if cleaned:
            sentences.append(cleaned)
            labels.append(tag)

    # 2. Add Systematic Augmentation for fractures
    if tag == 'fracture':
        for part in body_parts:
            for syn in fracture_synonyms:
                # OPTION A: "ribs fractured"
                phrase1 = clean_text(f"{part} {syn}")
                if phrase1:
                    sentences.append(phrase1)
                    labels.append(tag) # Correctly paired

                # OPTION B: "i think i broke my ribs"
                phrase2 = clean_text(f"i think i {syn} my {part}")
                if phrase2:
                    sentences.append(phrase2)
                    labels.append(tag) # Correctly paired

# Final sanity check print
print(f"Total Sentences (X): {len(sentences)}")
print(f"Total Labels (Y): {len(labels)}")
# These two numbers MUST be identical now.

# 4. Tokenization & Model
vocab_size = 1000
max_len = 15
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

lbl_encoder = LabelEncoder()
training_labels = lbl_encoder.fit_transform(labels)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, 32, input_length=max_len),
    tf.keras.layers.Conv1D(64, 3, activation='relu'),
    # Use Max Pooling to catch the specific 'fracture' signal
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(len(lbl_encoder.classes_), activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(padded_sequences, np.array(training_labels), epochs=120, verbose=1)


# 6. Export Files
# (Same export code as before for .tflite, vocab.json, and labels.txt)

# 5. Export to TFLite (Optimized for Mobile)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
# Optional: converter.optimizations = [tf.lite.Optimize.DEFAULT] # Adds Quantization (Smaller model)
tflite_model = converter.convert()

with open('med_intent-4.tflite', 'wb') as f:
    f.write(tflite_model)

# 6. SAVE THESE FOR YOUR TEAMMATES
# vocab.json: For the "Tokenizer Bridge" task
with open('vocab-4.json', 'w') as f:
    json.dump(word_index, f)

# labels.txt: The map for the UI to display the right name
with open('labels-4.txt', 'w') as f:
    for label in lbl_encoder.classes_:
        f.write(label + '\n')

print("\n--- ALL DONE ---")
print("Download these from the sidebar: med_intent-4.tflite, vocab-4.json, labels-4.txt")
# Out:
# Total Sentences (X): 1081
# Total Labels (Y): 1081
# Epoch 1/120
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.0962 - loss: 3.9351
# Epoch 2/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1811 - loss: 3.8245
# Epoch 3/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1690 - loss: 3.6297
# Epoch 4/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1751 - loss: 3.3979
# Epoch 5/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2069 - loss: 3.2174
# Epoch 6/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2117 - loss: 3.1410
# Epoch 7/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2617 - loss: 2.8813
# Epoch 8/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2961 - loss: 2.7456
# Epoch 9/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3401 - loss: 2.5702
# Epoch 10/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3742 - loss: 2.3106
# Epoch 11/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4183 - loss: 2.0986
# Epoch 12/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5026 - loss: 1.8291
# Epoch 13/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5393 - loss: 1.6953
# Epoch 14/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5989 - loss: 1.4728
# Epoch 15/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6457 - loss: 1.2923
# Epoch 16/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6554 - loss: 1.2572
# Epoch 17/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6967 - loss: 1.0904
# Epoch 18/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7415 - loss: 0.9571
# Epoch 19/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7565 - loss: 0.9057
# Epoch 20/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7485 - loss: 0.8396
# Epoch 21/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8097 - loss: 0.7367
# Epoch 22/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8197 - loss: 0.6588
# Epoch 23/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8161 - loss: 0.6545
# Epoch 24/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8289 - loss: 0.6376
# Epoch 25/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8601 - loss: 0.5692
# Epoch 26/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8435 - loss: 0.5472
# Epoch 27/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8557 - loss: 0.5124
# Epoch 28/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8792 - loss: 0.4430
# Epoch 29/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8755 - loss: 0.4613
# Epoch 30/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8821 - loss: 0.4021
# Epoch 31/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9043 - loss: 0.3422
# Epoch 32/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8793 - loss: 0.4096
# Epoch 33/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8809 - loss: 0.3963
# Epoch 34/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8880 - loss: 0.3620
# Epoch 35/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.3109
# Epoch 36/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9092 - loss: 0.3305
# Epoch 37/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9219 - loss: 0.2781
# Epoch 38/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9106 - loss: 0.3324
# Epoch 39/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9318 - loss: 0.2616
# Epoch 40/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9183 - loss: 0.2709
# Epoch 41/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8969 - loss: 0.3184
# Epoch 42/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9194 - loss: 0.2731
# Epoch 43/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9307 - loss: 0.2694
# Epoch 44/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8991 - loss: 0.2937
# Epoch 45/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9183 - loss: 0.2702
# Epoch 46/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9145 - loss: 0.2474
# Epoch 47/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9330 - loss: 0.2246
# Epoch 48/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9102 - loss: 0.2769
# Epoch 49/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9354 - loss: 0.2216
# Epoch 50/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9428 - loss: 0.1815
# Epoch 51/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9219 - loss: 0.2449
# Epoch 52/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9390 - loss: 0.2121
# Epoch 53/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9479 - loss: 0.1968
# Epoch 54/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9509 - loss: 0.1839
# Epoch 55/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9295 - loss: 0.2269
# Epoch 56/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9435 - loss: 0.2019
# Epoch 57/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9295 - loss: 0.2082
# Epoch 58/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9483 - loss: 0.1649
# Epoch 59/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9525 - loss: 0.1748
# Epoch 60/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9532 - loss: 0.1881
# Epoch 61/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9490 - loss: 0.1837
# Epoch 62/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9491 - loss: 0.1934
# Epoch 63/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9456 - loss: 0.1787
# Epoch 64/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9384 - loss: 0.1919
# Epoch 65/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9517 - loss: 0.1533
# Epoch 66/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.1397
# Epoch 67/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9523 - loss: 0.1571
# Epoch 68/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9413 - loss: 0.1781
# Epoch 69/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9360 - loss: 0.1913
# Epoch 70/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9435 - loss: 0.2028
# Epoch 71/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9382 - loss: 0.1809
# Epoch 72/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9522 - loss: 0.1594
# Epoch 73/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9435 - loss: 0.1710
# Epoch 74/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9430 - loss: 0.1662
# Epoch 75/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9494 - loss: 0.1710
# Epoch 76/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9421 - loss: 0.1785
# Epoch 77/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.1428
# Epoch 78/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9429 - loss: 0.1699
# Epoch 79/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9534 - loss: 0.1671
# Epoch 80/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9532 - loss: 0.1546
# Epoch 81/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9574 - loss: 0.1396
# Epoch 82/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9561 - loss: 0.1425
# Epoch 83/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.1557
# Epoch 84/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9552 - loss: 0.1331
# Epoch 85/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9562 - loss: 0.1501
# Epoch 86/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9485 - loss: 0.1373
# Epoch 87/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9650 - loss: 0.1261
# Epoch 88/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9666 - loss: 0.1306
# Epoch 89/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9451 - loss: 0.1468
# Epoch 90/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9446 - loss: 0.1515
# Epoch 91/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9475 - loss: 0.1629
# Epoch 92/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9477 - loss: 0.1680
# Epoch 93/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9636 - loss: 0.1351
# Epoch 94/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.1382
# Epoch 95/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9608 - loss: 0.1073
# Epoch 96/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9621 - loss: 0.1052
# Epoch 97/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.1264
# Epoch 98/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9727 - loss: 0.1140
# Epoch 99/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9648 - loss: 0.1200
# Epoch 100/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9561 - loss: 0.1270
# Epoch 101/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9617 - loss: 0.1246
# Epoch 102/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.1431
# Epoch 103/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9701 - loss: 0.1035
# Epoch 104/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9576 - loss: 0.1162
# Epoch 105/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9429 - loss: 0.1442
# Epoch 106/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9603 - loss: 0.1107
# Epoch 107/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9515 - loss: 0.1265
# Epoch 108/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9666 - loss: 0.1050
# Epoch 109/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9706 - loss: 0.1065
# Epoch 110/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9621 - loss: 0.1256
# Epoch 111/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9558 - loss: 0.1108
# Epoch 112/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9759 - loss: 0.0936
# Epoch 113/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9553 - loss: 0.1060
# Epoch 114/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9697 - loss: 0.1090
# Epoch 115/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9497 - loss: 0.1382
# Epoch 116/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9685 - loss: 0.0931
# Epoch 117/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9630 - loss: 0.0984
# Epoch 118/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9495 - loss: 0.1429
# Epoch 119/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9622 - loss: 0.1126
# Epoch 120/120
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9715 - loss: 0.1016
# Saved artifact at '/tmp/tmp237iue9k'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 15), dtype=tf.float32, name='keras_tensor_48')
# Output Type:
#   TensorSpec(shape=(None, 52), dtype=tf.float32, name=None)
# Captures:
#   135209947200400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619423952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619420496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619424336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207852456464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619424720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135207619425104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# --- ALL DONE ---
# Download these from the sidebar: med_intent.tflite, vocab.json, labels.txt

# %%
def predict_intent(text):
    # 1. Pre-process the input string
    sequence = tokenizer.texts_to_sequences([text.lower()])
    padded = pad_sequences(sequence, maxlen=max_len, truncating=trunc_type)

    # 2. Run prediction
    prediction = model.predict(padded)

    # 3. Get the label with the highest probability
    class_idx = np.argmax(prediction)
    tag = lbl_encoder.inverse_transform([class_idx])[0]
    confidence = prediction[0][class_idx]

    return tag, confidence

# --- TEST IT HERE ---
test_sentences = [
    "I'm bleeding really bad from a knife cut",
    "My friend passed out and isn't waking up",
    "I have a sharp pain in my chest",
    "Help I think i got my arms fractured"
]

for sentence in test_sentences:
    intent, prob = predict_intent(sentence)
    print(f"Text: {sentence}")
    print(f"AI Prediction: {intent} ({prob*100:.2f}% confidence)\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# Text: I'm bleeding really bad from a knife cut
# AI Prediction: severe_bleeding (78.84% confidence)
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Text: My friend passed out and isn't waking up
# AI Prediction: unconscious_unresponsive (65.05% confidence)
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Text: I have a sharp pain in my chest
# AI Prediction: severe_bleeding (61.95% confidence)
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Text: Help I think i got my arms fractured
# AI Prediction: head_injury (19.77% confidence)

# %%
import numpy as np

# 1. The Preprocessing Function (Must be identical to training)
STOP_WORDS = ["help", "i", "think", "got", "my", "me", "the", "a", "an", "please", "somebody", "do", "does"]

def clean_text_test(text):
    text = text.lower()
    for char in '?!.,':
        text = text.replace(char, '')
    words = text.split()
    filtered = [w for w in words if w not in STOP_WORDS]
    return " ".join(filtered)

# 2. The Prediction Function
def predict_emergency(raw_text):
    # Step 1: Clean
    cleaned = clean_text_test(raw_text)

    # Step 2: Tokenize and Pad
    sequence = tokenizer.texts_to_sequences([cleaned])
    padded = pad_sequences(sequence, maxlen=max_len, padding='post')

    # Step 3: Inference
    pred = model.predict(padded, verbose=0)

    # Step 4: Map back to Label
    class_idx = np.argmax(pred)
    tag = lbl_encoder.inverse_transform([class_idx])[0]
    confidence = pred[0][class_idx]

    return cleaned, tag, confidence

# 3. RUN THE STRESS TEST
test_cases = [
    "Help I think i got my ribs fractured", # Your problematic case
    "Someone please help me, my chest hurts",
    "I have a minor cut on my finger",
    "Help somebody is having a seizure",
    "I think I swallowed some poison",
    "My friend passed out and isn't waking up"
]

print(f"{'Original Text':<40} | {'Cleaned':<20} | {'Prediction':<15} | {'Conf.'}")
print("-" * 95)

for text in test_cases:
    cleaned, tag, conf = predict_emergency(text)
    print(f"{text:<40} | {cleaned:<20} | {tag:<15} | {conf:.2%}")
# Out:
# Original Text                            | Cleaned              | Prediction      | Conf.
# -----------------------------------------------------------------------------------------------
# Help I think i got my ribs fractured     | ribs fractured       | fracture        | 99.99%
# Someone please help me, my chest hurts   | someone chest hurts  | chest_pain      | 96.41%
# I have a minor cut on my finger          | have minor cut on finger | cuts            | 99.96%
# Help somebody is having a seizure        | is having seizure    | seizure         | 98.72%
# I think I swallowed some poison          | swallowed some poison | poisoning       | 97.15%
# My friend passed out and isn't waking up | friend passed out and isn't waking up | unconscious_unresponsive | 90.61%

# %%
def final_stress_test():
    test_cases = [
        "Help I think i got my ribs fractured",
        "My wrist is broken help",
        "I think I'm drowning",
        "i have a fracture in my leg"
    ]

    print(f"{'Input':<40} | {'Prediction'}")
    print("-" * 60)
    for test in test_cases:
        _, tag, conf = predict_emergency(test) # Using the function from earlier
        print(f"{test:<40} | {tag} ({conf:.2%})")

final_stress_test()
# Out:
# Input                                    | Prediction
# ------------------------------------------------------------
# Help I think i got my ribs fractured     | fracture (99.99%)
# My wrist is broken help                  | fracture (99.61%)
# I think I'm drowning                     | drowning (99.83%)
# i have a fracture in my leg              | fracture (79.61%)

# %%
test_phrase = "Help I think i got my ribs fractured"
cleaned = clean_text(test_phrase)
seq = tokenizer.texts_to_sequences([cleaned])
padded = pad_sequences(seq, maxlen=max_len, padding='post')
pred = model.predict(padded, verbose=0)
tag = lbl_encoder.inverse_transform([np.argmax(pred)])[0]

print(f"Input: {test_phrase}")
print(f"Cleaned: {cleaned}")
print(f"Result: {tag} ({np.max(pred):.2%})")
# Out:
# Input: Help I think i got my ribs fractured
# Cleaned: ribs fractured
# Result: fracture (100.00%)

# %%
import json

def update_intents_json(file_path):
    # 1. Load the existing file
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # 2. Define our augmentation data (from your previous logic)
    body_parts = ["ribs", "chest", "skull", "wrist", "ankle", "hip", "spine", "nose", "toe", "shoulder", "jaw"]
    fracture_synonyms = ["fractured", "broken", "cracked", "snapped"]

    # 3. Find the fracture intent and update it
    for intent in data['intents']:
        if intent['tag'] == 'fracture':
            # Get existing patterns to avoid duplicates
            existing_patterns = set(intent['patterns'])

            new_count = 0
            for part in body_parts:
                for syn in fracture_synonyms:
                    # Create two common variations
                    p1 = f"{part} {syn}"
                    p2 = f"I think I {syn} my {part}"

                    if p1 not in existing_patterns:
                        intent['patterns'].append(p1)
                        existing_patterns.add(p1)
                        new_count += 1

                    if p2 not in existing_patterns:
                        intent['patterns'].append(p2)
                        existing_patterns.add(p2)
                        new_count += 1

            print(f"Added {new_count} new patterns to the 'fracture' tag.")

    # 4. Save the final JSON back to the file
    # We use indent=4 to keep it readable for your teammates
    with open(file_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, indent=4)

    print(f"Successfully updated {file_path}")

# Execute
update_intents_json('intents.json')
# Out:
# Added 88 new patterns to the 'fracture' tag.
# Successfully updated intents.json
